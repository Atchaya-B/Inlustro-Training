# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_csv("/content/Salary_Data.csv")

# %%
data.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.tail(5)
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
data.shape
# Out:
# (30, 2)

# %%
print("Number of duplicate data:",data.shape)
# Out:
# Number of duplicate data: (30, 2)

# %%
data.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x=data["YearsExperience"]
y=data["Salary"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=45)

# %%
model=LinearRegression()

# %%
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mse)
print(r2)
# Out:
# 37274483.53687438
# 0.9452086365937471

# %%
plt.scatter(x,y,color="green")
plt.plot(x_test,y_pred,color="red")
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,7))
sns.barplot(x="YearsExperience",y="Salary",data=data,color="red")
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="YearsExperience",data=data,color="green")
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
import seaborn as sns

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="YearsExperience",data=data,bins=10,kde=True,color="green")
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()
